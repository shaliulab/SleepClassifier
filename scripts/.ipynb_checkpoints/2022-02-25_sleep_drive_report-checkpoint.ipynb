# %%
import os.path
import glob
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import ipyplot
import yaml

# %%
# please select here the background 
BACKGROUND = "glia"
BACKGROUND = "KC"
# last one uncommented is selected

# %%
CONFUSION_TABLE_ENABLED=True
METRICS_ENABLED=True
CROSSANALYSIS_ENABLED=False

# %%
# dont change any code from here on

# %%
RESULTS_ROOT = "../results/"
RESULTS_DIR = os.path.join(RESULTS_ROOT, f"{BACKGROUND}-models", "NN")
SEED=1000
fraction=1.0
RESULTS_DIR
# Out:
# '../results/KC-models/NN'

# %%
celltypes = glob.glob(os.path.join(RESULTS_DIR, "*"))

# %%
def get_celltype_and_folder(folder):
    celltype = os.path.basename(celltype_folder)
    results_dir = os.path.join(celltype_folder, f"random-state_{SEED}_fraction_{fraction}")
    return celltype, results_dir

# %%
confusion_tables = []
accuracy_d = {}
accuracy_table = {}
for celltype_folder in celltypes:
    celltype, results_dir = get_celltype_and_folder(celltype_folder)
    
    # read the confusion table between sleep drive conditions for the same celltype
    if CONFUSION_TABLE_ENABLED:
        confusion_table_file = os.path.join(results_dir, f"{celltype}_confusion_table.png")
        confusion_table = cv2.imread(confusion_table_file)
        print(celltype)
        confusion_tables.append(confusion_table)
    
    
    # read the metrics of each celltype.
    if METRICS_ENABLED:
        metrics_file = os.path.join(results_dir, f"{celltype}_metrics.yaml")
        with open(metrics_file, "r") as filehandle:
                metrics = yaml.load(filehandle, yaml.SafeLoader)

        accuracy = metrics["test-accuracy"]
        accuracy_d[celltype] = accuracy
    
    # read the metrics of the models trained on each celltype and run on all celltypes
    if CROSSANALYSIS_ENABLED:
        for celltype_folder in celltypes:
            datatype, data_results_dir = get_celltype_and_folder(celltype_folder)

            data_metrics_file = os.path.join(results_dir, f"{datatype}_metrics.yaml")
            with open(data_metrics_file, "r") as filehandle:
                metrics = yaml.load(filehandle, yaml.SafeLoader)
                accuracy = metrics["test-accuracy"]
                if celltype in accuracy_table:          
                    accuracy_table[celltype][datatype] = accuracy
                else:
                    accuracy_table[celltype] = {datatype: accuracy}
# Out:
# ab
# abp
# y

# %%
if CONFUSION_TABLE_ENABLED: ipyplot.plot_images(confusion_tables, max_images=10, img_width=300)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-iGpQbsUmsauDAv6nhtXEaY {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-iGpQbsUmsauDAv6nhtXEaY {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-iGpQbsUmsauDAv6nhtXEaY {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-iGpQbsUmsauDAv6nhtXEaY:checked ~ #ipyplot-html-viewer-textarea-iGpQbsUmsauDAv6nhtXEaY {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-iGpQbsUmsauDAv6nhtXEaY:checked + #ipyplot-html-viewer-label-iGpQbsUmsauDAv6nhtXEaY:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-iGpQbsUmsauDAv6nhtXEaY">
#         <label id="ipyplot-html-viewer-label-iGpQbsUmsauDAv6nhtXEaY" for="ipyplot-html-viewer-toggle-iGpQbsUmsauDAv6nhtXEaY">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-iGpQbsUmsauDAv6nhtXEaY" readonly>
#
#         <style>
#         #ipyplot-imgs-container-div-4HNqTuAnQySrMyfzrPVUJM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-4HNqTuAnQySrMyfzrPVUJM">
#     <div class="ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM">
#         <div id="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-92xUENWs2mQzKA7iAABxjP" class="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-92xUENWs2mQzKA7iAABxjP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM">
#         <div id="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-c8qExDuZs6HvSjrtoxmryq" class="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-c8qExDuZs6HvSjrtoxmryq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM">
#         <div id="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-HAvxP4bKTtywvYtGdHJkCB" class="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-HAvxP4bKTtywvYtGdHJkCB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>
#         </textarea>
#     </div>
#         <style>
#         #ipyplot-imgs-container-div-4HNqTuAnQySrMyfzrPVUJM {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM {
#             width: 300px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM {
#             width: 300px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM img {
#             width: 300px;
#         }
#
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-4HNqTuAnQySrMyfzrPVUJM">
#     <div class="ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM">
#         <div id="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-92xUENWs2mQzKA7iAABxjP" class="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-92xUENWs2mQzKA7iAABxjP">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM">
#         <div id="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-c8qExDuZs6HvSjrtoxmryq" class="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-c8qExDuZs6HvSjrtoxmryq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-4HNqTuAnQySrMyfzrPVUJM">
#         <div id="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-HAvxP4bKTtywvYtGdHJkCB" class="ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <img src="data:image/png;base64,..."/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-4HNqTuAnQySrMyfzrPVUJM-HAvxP4bKTtywvYtGdHJkCB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div>

# %%
if METRICS_ENABLED:
    plt.bar(accuracy_d.keys(), accuracy_d.values())
    plt.ylim([0, 100])

# %%
if CROSSANALYSIS_ENABLED:
    pass
